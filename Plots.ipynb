# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
hopper = np.load("learning_curves/Hopper/TD3_Hopper-v1_9.npy")
plt.plot(hopper)
plt.xlabel("Iterations")
plt.ylabel("Average Reward")
plt.savefig("Hopper_plot.png")
plt.show()

# %%
hopper = np.load("learning_curves/Walker/TD3_Walker2d-v1_9.npy")
plt.plot(hopper)
plt.xlabel("Iterations")
plt.ylabel("Average Reward")
plt.savefig("Walker_plot.png")
plt.show()

# %%
hopper = np.load("learning_curves/HalfCheetah/TD3_HalfCheetah-v1_7.npy")
plt.plot(hopper)
plt.xlabel("Iterations")
plt.ylabel("Average Reward")
plt.savefig("HalfCheetah_plot.png")
plt.show()
